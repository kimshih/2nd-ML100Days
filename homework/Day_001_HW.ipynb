# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, yp):
    """
    請完成這個 Function 後往下執行
    
    Args:
        - y: 實際值
        - yp: 預測值
    """
    mse = 1/len(y) * sum((y - yp)**2)
    return mse

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 231.547
# The Mean absolute error is 12.313

# %% [markdown]
# # 作業1

# %% [markdown]
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
# Chicago Taxi Rides 2016
# 1. 你選的這組資料為何重要
#  - 欲解決城市交通問題, 可透過計程車紀錄分析及預測
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#  - made publically available by the City of Chicago at: https://data.cityofchicago.org/Transportation/Taxi-Trips/wrvz-psew
# 3. 蒐集而來的資料型態為何
#  - 結構化資料, 機關將資料放在database, 讓user可透過BigQuery查詢, 我找到有人已另存部分資料為csv
# 4. 這組資料想解決的問題如何評估
#  - 可先以搭乘時間點, 地區, 金額去分析peak hour, hot spot等, vs 當地metro再做進一步分析

# %% [markdown]
# # 作業2

# %% [markdown]
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#  - 提升業績可從以下3點breakdown, 由於此題scope很大, 我選擇先從b.增加乘客<br>
#  a.增加司機<br>
#  b.增加乘客<br>
#  c.改變收費機制<br>
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#  - 增加乘客可再細分以下方法a.增加用戶體驗/b.增加新用戶/c.增加既有用戶持續坐的次數 , 因此需要的資料列舉以下<br>
#  a.用戶滿意度調查/NPS data<br>
#  b.過去Campaign data<br>
#  c.customer usage data (包含時間, 頻率, 地理資訊)<br>
#  d.customer demographic data (職業, 性別, 年齡, 地址等)<br>
# 3. 蒐集而來的資料型態為何
#  - 結構化資料, 可能是excel or from database
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#  - 方法: 針對new customers or existing customers 設計各種不同Campaign以達到目的
#  - 驗證: response rate, 建模預測高機率用戶: ROC
